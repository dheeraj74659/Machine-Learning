# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/stock.csv')

# %%
df.dtypes
# Out:
# Date      object
# Open     float64
# High     float64
# Low      float64
# Close    float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                    Date      Open      High       Low     Close
# 0      03-12-2012 09:16  12125.70  12161.70  12125.70  12160.95
# 1      03-12-2012 09:17  12161.75  12164.80  12130.40  12130.40
# 2      03-12-2012 09:18  12126.85  12156.10  12126.85  12156.10
# 3      03-12-2012 09:19  12157.25  12164.75  12151.60  12164.20
# 4      03-12-2012 09:20  12162.80  12162.80  12148.20  12151.15
# ...                 ...       ...       ...       ...       ...
# 14995  01-04-2013 15:26  11417.95  11417.95  11411.45  11411.45
# 14996  01-04-2013 15:27  11409.30  11410.90  11406.45  11409.95
# 14997  01-04-2013 15:28  11412.30  11418.35  11412.15  11414.35
# 14998  01-04-2013 15:29  11414.90  11418.05  11410.60  11410.60
# 14999  01-04-2013 15:30  11411.15  11419.00  11410.65  11415.00
#
# [15000 rows x 5 columns]>

# %%
df =  df.iloc[:2000,:]

# %%
df.info
# Out:
# <bound method DataFrame.info of                   Date      Open      High       Low     Close
# 0     03-12-2012 09:16  12125.70  12161.70  12125.70  12160.95
# 1     03-12-2012 09:17  12161.75  12164.80  12130.40  12130.40
# 2     03-12-2012 09:18  12126.85  12156.10  12126.85  12156.10
# 3     03-12-2012 09:19  12157.25  12164.75  12151.60  12164.20
# 4     03-12-2012 09:20  12162.80  12162.80  12148.20  12151.15
# ...                ...       ...       ...       ...       ...
# 1995  10-12-2012 11:16  12377.25  12379.60  12376.60  12377.70
# 1996  10-12-2012 11:17  12379.15  12381.80  12379.10  12381.75
# 1997  10-12-2012 11:18  12381.30  12383.00  12381.20  12382.40
# 1998  10-12-2012 11:19  12381.50  12382.00  12377.40  12377.40
# 1999  10-12-2012 11:20  12376.60  12376.60  12372.85  12375.60
#
# [2000 rows x 5 columns]>

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind = 'kde')

# %%
df.plot(kind = 'line')

# %%
df.plot(kind = 'hist')

# %%
plt.figure(figsize = (20, 20))
plt.plot(df['Date'].iloc[:200], df['Close'].iloc[:200])

# %%
x = df.iloc[:1000, -1].values.reshape(-1,1)
y = df.iloc[1:1001, -1].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

lr.fit(x, y)
# Out:
# LinearRegression()

# %%
x_test = df.iloc[1001:1021, -1].values.reshape(-1,1)
y_test = df.iloc[1002:1022, -1].values.reshape(-1,1)

# %%
y1 = lr.predict(x)

# %%
for i, j, k in zip(x, y1, y):
    print(i, j, k)
# Out:
# [12160.95] [12272.23603025] [12130.4]
# [12130.4] [12279.37161335] [12156.1]
# [12156.1] [12276.42756158] [12164.2]
# [12164.2] [12287.25568419] [12151.15]
# [12151.15] [12283.96233814] [12158.15]
# [12158.15] [12285.5092128] [12146.05]
# [12146.05] [12290.09993759] [12152.95]
# [12152.95] [12289.90034086] [12152.55]
# [12152.55] [12293.44318282] [12143.2]
# [12143.2] [12294.19167056] [12138.65]
# [12138.65] [12295.53894848] [12136.8]
# [12136.8] [12297.08582314] [12134.]
# [12134.] [12292.54499753] [12154.1]
# [12154.1] [12296.28743622] [12154.55]
# [12154.55] [12291.29751797] [12161.5]
# [12161.5] [12286.60699482] [12155.45]
# [12155.45] [12286.05810381] [12159.8]
# [12159.8] [12281.46737902] [12164.6]
# [12164.6] [12280.51929455] [12159.1]
# [12159.1] [12275.77887221] [12158.1]

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y1)
# Out:
# 0.634623955973803
